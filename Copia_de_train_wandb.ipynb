# %%
# prompt: mount drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Usage example in Colab:
#!pip install wandb
import wandb
wandb.login()
# %run /content/drive/MyDrive/1st_paper/train_wandb.py
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: sblas (sblas-universidad-nacional-del-litoral) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.7
# Run data is saved locally in <code>/content/wandb/run-20250409_044752-ma7rx26i</code>
# Syncing run <strong><a href='https://wandb.ai/sblas-universidad-nacional-del-litoral/uncategorized/runs/ma7rx26i' target="_blank">effortless-sponge-6</a></strong> to <a href='https://wandb.ai/sblas-universidad-nacional-del-litoral/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/sblas-universidad-nacional-del-litoral/uncategorized' target="_blank">https://wandb.ai/sblas-universidad-nacional-del-litoral/uncategorized</a>
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

df = pd.read_csv('/path/to/fold_1/test_latent_space_fold_1.csv')
labels = df['label']
mu = df.drop(columns=['label']).values  # shape (N, latent_dim)

pca = PCA(n_components=2)
mu_2d = pca.fit_transform(mu)
plt.scatter(mu_2d[:,0], mu_2d[:,1], c=some_color_map(labels))
plt.show()

# %%
# %run /content/drive/MyDrive/1st_paper/train.py \
  --folds_dir /home/diego/Escritorio/santiago/1st_paper/ \
  --num_folds 5 \
  --epochs 1000 \
  --batch_size 16 \
  --latent_dim 250 \
  --beta 4.9 \
  --dropout 0.01 \
  --lr 0.007 \
  --weight_decay 0.000000017 \
  --early_stop 100 \
  --plot_losses

# %%
# %load_ext tensorboard
# %tensorboard --logdir '/content/drive/MyDrive/1st_paper'

# %%
import wandb
wandb.login()

# %%
# %run /content/drive/MyDrive/1st_paper/train_wandb.py
